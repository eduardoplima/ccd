# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from utils_ccd import get_connection

conn = get_connection()
conn_processo = get_connection()

# %%
sql_processos = """ SELECT DISTINCT p.IdProcesso as id, p.numero_processo, 
	p.ano_processo,
	pm.Descricao as marcador
FROM processo.dbo.Processos p 
    LEFT JOIN processo.dbo.Itens_Lote i ON p.IdProcesso = i.IdProcesso
    LEFT JOIN processo.dbo.Lotes l ON i.IdLote = l.IdLote
    LEFT JOIN processo.dbo.Pro_MarcadorProcesso pmp ON p.IdProcesso = pmp.IdProcesso 
    LEFT JOIN processo.dbo.Pro_Marcador pm ON pmp.IdMarcador = pm.IdMarcador
    WHERE l.origem = 'DIP'
    ORDER BY  p.IdProcesso
    """

# %%
df_processos = pd.read_sql(sql_processos, get_connection())
# Out:
# /tmp/ipykernel_257785/2926778259.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_processos = pd.read_sql(sql_processos, get_connection())

# %%
df_processos.fillna('Sem marcador', inplace=True)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='id', y='marcador', data=df_processos, palette='viridis')
plt.title('Quantidade de Processos por Marcador')
plt.xlabel('Quantidade')
plt.ylabel('Marcador')
sns.despine(top=True, right=True)
plt.show()
# Out:
# /tmp/ipykernel_257785/984083368.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='id', y='marcador', data=df_processos, palette='viridis')

# %%
len(df_processos.marcador.unique())
# Out:
# 139

# %%
df_processos.marcador.unique()
# Out:
# array(['Sem marcador', 'VOTO - Prescrição DECENAL',
#        'Parecer - Prescrição', 'Despacho para arquivo',
#        'CONTROLE/FISCALIZAÇÃO', 'Prescrição - Quinquenal ou Decenal',
#        'INSTAURAR PROCESSO DE EXECUÇÃO', 'VOTO', 'Tramitação interna',
#        'DESPACHOS PARA ASSINAR', 'PARECER FINALIZADO E INFO NÃO INCLUÍDA',
#        'ARQUIVAMENTO', 'Despachos', 'VOTO - Prescrição QUINQUENAL',
#        'ALIMENTAR CADASTRO - MONITORAMENTO', 'Enviar para o MPJTC',
#        'PARECER FINALIZADO / INFO INCLUÍDA', 'DESPACHO PRONTO',
#        'Voto simples - prescrição - dano ao erário',
#        'EM PAUTA - PENDENTE DE DECISÃO', 'Elaborar despacho de ordem',
#        'MANIFESTAÇÃO CORPO TÉCNICO',
#        'VOTO - PRESCRIÇÃO RESSARCIMENTO TEMA 899 STF',
#        'VOTO - Prescrição EXECUTÓRIA', 'Para Arquivar', 'VOTO PRONTO',
#        '31 II DCD', 'DEFESA - DAM_FGO', 'PARCELAMENTO EM CURSO',
#        'Análise de defesa/recurso LRF', 'DESCONTO EM FOLHA - Nereu',
#        'VOTO - EM ELABORAÇÃO', 'Ciência/posicionamento do MPC',
#        'RECURSO NO PRAZO', 'VOTO PARA REVISÃO CLEBER',
#        '3. Sigilosos - PENDENTE DE TRIAGEM', 'PFA', 'Defesa - DCP',
#        'PRESCRIÇÃO', 'AGUARDANDO ENTREGA - EMAIL',
#        'BAIXA NA RESPONSABILIDADE', 'DIRETOR - ASSINAR',
#        'AGUARDANDO IMPRESSÃO - VANYA', 'Prescrição Trienal',
#        'Defesa - Conclusivo', 'DÚVIDAS E ERROS RESOLVER', 'Para revisão',
#        'LUZENILDO - Enviar à DIP',
#        'SOBRESTADO - Aguardando para execução posterior',
#        'Prescrição Intercorrente', 'Instrução Geral',
#        'CERTIFICAR - SEM DOC', 'Recurso Reconsideração',
#        'DESPACHO - DE - Arquivamento', 'Decisão Judicial',
#        'Instrução - DAD',
#        'Instrução Processual - Análise de defesa/recurso Contas Anuais 2014 e 2015',
#        'Antecedentes', 'Outras Situações', 'Acúmulo de Cargos',
#        'PROTESTO - CANCELAMENTO E PROVIDENCIAS',
#        'Câmara - Contas de Governo', 'Atuação Rem. Agentes Políticos',
#        'Aguardando triagem', 'DEFESA - DAM_FGE', 'X_EXCLUIR MARCADOR',
#        'SOBRESTADO - Decisão judicial',
#        'Instrução Preliminar Sumária - Fatos Pretéritos',
#        'Ofícios/Documentos', 'APENSAMENTO', 'Instrução - Governo Cidadão',
#        'AGUARDANDO ENTREGA - CORREIOS - MARÇO',
#        'CERTIFICAR - TRÂNSITO EM JULGADO - ARQUIVO',
#        'DESPESA COM PESSOAL', 'ERROS - REFAZER',
#        'PRAZO 2025: MARÇO (01-15)',
#        'PROTESTO ELETRÔNICO - CONFIRMAÇÃO DE ENVIO',
#        'Análise Inicial - Coordenação', 'Check list', 'Fazer despacho',
#        'Excesso de Contratação Temporária', 'Para apensamento',
#        'EXPEDIR MANDADOS', 'VOTO - PLENO',
#        'Instrução Processual - Análise de defesa/recurso Contas Anuais 2016 e 2017',
#        'Multas para inscrição via Portal das Procuradorias',
#        'Câmara - Outros', 'QUANTIFICAR MULTA',
#        '02. CADASTRO GERAL DE ACOMPANHAMENTO DE DECISÕES',
#        'Instrução - Manifestação Complementar', 'Instrução - Apensamento',
#        'TAG', 'Pleno - Arquivamento', 'DESPACHO DE ORDEM - DDP E MP',
#        'DESPACHO - ANTECEDENTES',
#        'DESCONTO EM FOLHA ACOMPANHAMENTO NEREU', 'Monitoramento CCD',
#        'DESCONTO EM FOLHA - SUSPENSÃO POR DECISÃO JUDICIAL',
#        'ATRIBUIÇÃO DE OUTRO SETOR',
#        'DECISÃO JUDICIAL SUSPENDENDO OS EFEITOS DO ACÓRDÃO',
#        'CERTIFICAR - TRÂNSITO EM JULGADO - DEMAIS PROVIDÊNCIAS', 'OFÍCIO',
#        'Estoque da COPCEX',
#        'Instrução Processual - Análise de defesa/recurso Contas Anuais 2018 a 2022',
#        'PRAZO 2025: ABRIL (16-30)', 'AGUARDANDO ENTREGA - HUMBERTO',
#        'para dr Ed revisar despacho',
#        'DESCONTO EM FOLHA ACOMPANHAMENTO GERAL',
#        'Instrução Preliminar Sumária - Concomitante',
#        'Triagem - retorno de diligência solicitad pela DAP',
#        'PRAZO 2025: MAIO (01-15)', 'Arquivamento voto',
#        'Processo concluído aguardando correção.', '31 II - DCC',
#        'Tomada de Contas', 'DESCONTO EM FOLHA',
#        'Instrução Processual - Análise de defesa/recurso Contas Trienal 2018/2019/2020',
#        'PRAZO 2025: ABRIL (01-15)', 'Voto simples - arquivamento',
#        'Arquivamento - DAE', 'AGUARDANDO ENTREGA - CORREIOS - FEVEREIRO',
#        'Denúncia', 'TRIAGEM', 'AGUARDANDO ENTREGA - CORREIOS - JANEIRO',
#        'Sobrestado', 'Decisão interlocutória',
#        'Instrução Processual - Análise de defesa/recurso Contas Trienal 2021/2022/2023',
#        'Seletivo e Prioritário', 'Multas - problemas no SICODE',
#        'Voto simples',
#        'Multa inscrita na dívida ativa via Sicode - Aguardando retorno da PGE',
#        'Protesto Efetivo Fevereiro/2025',
#        'Para correção - Carlos e Paulo', 'Decisão pronta',
#        'PROTESTO ELETRÔNCIO - Revisar antes de enviar',
#        'Instrução - Precatorios - REL', 'EM REVISÃO C/ COORD.',
#        'Instrução Preliminar Sumária', 'Análise pela Diretoria'],
#       dtype=object)
