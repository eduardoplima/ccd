# %%
import os
import pymssql

import pandas as pd
import numpy as np

from dotenv import load_dotenv
from utils_ccd import get_connection

# %%
load_dotenv()
# Out:
# True

# %%
conn = get_connection()

# %%
descontos_sql = ''' SELECT pro.numero_processo,
       pro.ano_processo,
       pm.Descricao
FROM processo.dbo.Processos pro
INNER JOIN processo.dbo.Pro_MarcadorProcesso pmp ON pmp.IdProcesso = pro.IdProcesso
INNER JOIN processo.dbo.Pro_Marcador pm ON pmp.IdMarcador = pm.IdMarcador 
WHERE pro.setor_atual = 'CCD'
AND lower(pm.Descricao) = 'DESCONTO EM FOLHA'
'''
processos_descontos = pd.read_sql(descontos_sql, conn)
# Out:
# /tmp/ipykernel_9261/4246048530.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   processos_descontos = pd.read_sql(descontos_sql, conn)

# %%
processos_descontos
# Out:
#    numero_processo ano_processo          Descricao
# 0           011032         2016  DESCONTO EM FOLHA
# 1           017229         2017  DESCONTO EM FOLHA
# 2           002138         2019  DESCONTO EM FOLHA
# 3           000088         2021  DESCONTO EM FOLHA
# 4           002570         2024  DESCONTO EM FOLHA
# 5           002573         2024  DESCONTO EM FOLHA
# 6           002574         2024  DESCONTO EM FOLHA
# 7           002594         2024  DESCONTO EM FOLHA
# 8           002595         2024  DESCONTO EM FOLHA
# 9           003368         2024  DESCONTO EM FOLHA
# 10          003391         2024  DESCONTO EM FOLHA
# 11          003396         2024  DESCONTO EM FOLHA
# 12          003398         2024  DESCONTO EM FOLHA
# 13          003406         2024  DESCONTO EM FOLHA
# 14          003408         2024  DESCONTO EM FOLHA
# 15          003411         2024  DESCONTO EM FOLHA
# 16          003414         2024  DESCONTO EM FOLHA
# 17          003419         2024  DESCONTO EM FOLHA
# 18          004772         2024  DESCONTO EM FOLHA
# 19          004773         2024  DESCONTO EM FOLHA
# 20          004867         2024  DESCONTO EM FOLHA
# 21          004876         2024  DESCONTO EM FOLHA
# 22          004886         2024  DESCONTO EM FOLHA
# 23          004888         2024  DESCONTO EM FOLHA
# 24          004893         2024  DESCONTO EM FOLHA
# 25          004896         2024  DESCONTO EM FOLHA
# 26          004903         2024  DESCONTO EM FOLHA
# 27          004923         2024  DESCONTO EM FOLHA
